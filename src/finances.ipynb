# %%
import plotly.express as px
import plotly.graph_objects as go
import numpy as np
import pandas as pd
from finances import Finances
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
initial_inv = 10000
monthly_inv = 1000
rate = 0.05
n_years = 25

fin = Finances(
  initial_inv=initial_inv, monthly_inv=monthly_inv, rate=rate, n_years=n_years
)
fin.finances
# Out:
#      investments        returns    n_years
# 0          10000   10000.000000   0.000000
# 1          11000   11041.666667   0.083333
# 2          12000   12087.673611   0.166667
# 3          13000   13138.038918   0.250000
# 4          14000   14192.780747   0.333333
# ..           ...            ...        ...
# 296       306000  615967.083773  24.666667
# 297       307000  619533.613289  24.750000
# 298       308000  623115.003345  24.833333
# 299       309000  626711.315858  24.916667
# 300       310000  630322.613008  25.000000
#
# [301 rows x 3 columns]

# %%
fin.plot_investments_vs_returns()

# %%
fin.yearly_finances
# Out:
#      investments  returns  n_years    gain  yearly_returns
# 0          10000    10000      0.0       0               0
# 12         22000    22790      1.0     790           12790
# 24         34000    36235      2.0    2235           13445
# 36         46000    50368      3.0    4368           14133
# 48         58000    65223      4.0    7223           14855
# 60         70000    80839      5.0   10839           15616
# 72         82000    97254      6.0   15254           16415
# 84         94000   114509      7.0   20509           17255
# 96        106000   132646      8.0   26646           18137
# 108       118000   151711      9.0   33711           19065
# 120       130000   171752     10.0   41752           20041
# 132       142000   192818     11.0   50818           21066
# 144       154000   214962     12.0   60962           22144
# 156       166000   238238     13.0   72238           23276
# 168       178000   262706     14.0   84706           24468
# ...

# %%
px.line(fin.yearly_finances, x="n_years", y="gain", log_y=False)
